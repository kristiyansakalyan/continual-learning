# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils.dataset_utils import Cataract1K, CadisDataset

cataract_ds = Cataract1K("data/catract-1k")
cadis_ds = CadisDataset("data/cadis", "test")

# %%
cadis_ds.categories
# Out:
# {1: 'Eye Retractors',
#  2: 'Hydro. Cannula',
#  3: 'Visco. Cannula',
#  4: 'Cap. Cystotome',
#  5: 'Rycroft Cannula',
#  6: 'Bonn Forceps',
#  7: 'Primary Knife',
#  8: 'Phaco. Handpiece',
#  9: 'Lens Injector',
#  10: 'A/I Handpiece',
#  11: 'Secondary Knife',
#  12: 'Micromanipulator',
#  13: 'Cap. Forceps',
#  14: 'Water Sprayer',
#  15: 'Suture Needle',
#  16: 'Needle Holder',
#  17: 'Charleux Cannula',
#  18: 'Vannas Scissors',
#  19: 'Viter. Handpiece',
#  20: 'Mendez Ring',
#  21: 'Biomarker',
#  22: 'Marker',
#  0: 'Background'}

# %%
cataract_ds.categories
# Out:
# {1: 'Cornea',
#  2: 'Katena Forceps',
#  3: 'cornea1',
#  4: 'Lens Injector',
#  5: 'Irrigation-Aspiration',
#  6: 'Capsulorhexis Forceps',
#  7: 'Spatula',
#  8: 'pupil1',
#  9: 'Phacoemulsification Tip',
#  10: 'Incision Knife',
#  11: 'Pupil',
#  12: 'Slit Knife',
#  13: 'Lens',
#  14: 'Capsulorhexis Cystotome',
#  15: 'Gauge',
#  0: 'Background'}

# %%
from utils.dataset_utils import get_cadis_dataset, get_cataract1k_dataset
from utils.vis_utils import overlay_mask_on_image

train, val, test = get_cadis_dataset("data/cadis", domain_incremental=True)
print(len(train), len(val), len(test))
# Out:
# 3584 540 614

# %%
img, mask = train[150]
overlay_mask_on_image(img, mask)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
train, val, test = get_cataract1k_dataset("data/catract-1k", split_ratios=[0.8, 0.1], domain_incremental=True)
print(len(train), len(val), len(test))
# Out:
# 1804 225 227

# %%
img, mask = train[390]
overlay_mask_on_image(img, mask)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from torch.utils.data import DataLoader

# Dataloading
N_WORKERS = 1
BATCH_SIZE = 16
SHUFFLE = True
DROP_LAST = False

# Setup datlaoader
train_loader = DataLoader(train, batch_size=BATCH_SIZE, shuffle=SHUFFLE, num_workers=N_WORKERS, drop_last=DROP_LAST, pin_memory=True)

for imgs, masks in train_loader:
    print(imgs.shape, masks.shape)
# Out:
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([16, 3, 768, 1024]) torch.Size([16, 768, 1024])
# torch.Size([12, 3, 768, 1024]) torch.Size([12, 768, 1024])

# %%
from torch.utils.data import DataLoader

# Dataloading
N_WORKERS = 1
BATCH_SIZE = 32
SHUFFLE = True
DROP_LAST = False

# Setup datlaoader
train_loader = DataLoader(train, batch_size=BATCH_SIZE, shuffle=SHUFFLE, num_workers=N_WORKERS, drop_last=DROP_LAST, pin_memory=True)

for imgs, masks in train_loader:
    print(imgs.shape, masks.shape)
# Out:
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
# torch.Size([32, 3, 540, 960]) torch.Size([32, 540, 960])
