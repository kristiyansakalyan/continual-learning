# %%
import torch
import torch.optim as optim
import torchvision.models.segmentation as segmentation
from utils.dataset_utils import CadisDataset
from torch.utils.data import DataLoader

# Import dataset
cadis_train_ds = CadisDataset(root_folder="data/cadis", split="train")

# %%
# Check if CUDA is available, otherwise use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Initialize model
model = segmentation.deeplabv3_resnet50(weights=None, progress=True, num_classes=len(cadis_train_ds.categories), aux_loss=None).to(device)

# %%
# Training
NUM_EPOCHS = 10
LEARNING_RATE = 1e-3

optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE)
criterion = torch.nn.CrossEntropyLoss()

# Dataloading
N_WORKERS = 4
BATCH_SIZE = 4
SHUFFLE = True
DROP_LAST = True

# %%
# Setup datlaoader
train_loader = DataLoader(cadis_train_ds, batch_size=BATCH_SIZE, shuffle=SHUFFLE, num_workers=N_WORKERS, drop_last=DROP_LAST, pin_memory=True)

# %%
model.train()
for epoch in range(NUM_EPOCHS):
    running_loss = 0.0
    
    for images, masks in train_loader:
        # Move data to the appropriate device (CPU or GPU)
        images = images.to(device)
        masks = masks.to(device)

        # Forward pass and loss
        outputs = model(images)['out']
        loss = criterion(outputs, masks)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * images.size(0)
        print(f'Current loss: {loss.item() * images.size(0):.4f}')

    epoch_loss = running_loss / len(train_loader.dataset)
    print(f'Epoch {epoch + 1}/{NUM_EPOCHS}, Loss: {epoch_loss:.4f}')
# Out:
# Current loss: 11.8595
# Current loss: 11.0702
# Current loss: 10.6685
# Current loss: 9.3348
# Current loss: 7.9100
# Current loss: 6.6818
# Current loss: 5.4127
# Current loss: 4.7492
# Current loss: 4.1290
# Current loss: 3.2264
# Current loss: 2.5744
# Current loss: 2.5615
# Current loss: 1.9092
# Current loss: 2.4272
# Current loss: 1.7428
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       8 masks = masks.to(device)
#      10 # Forward pass and loss
# ---> 11 outputs = model(images)['out']
#      12 loss = criterion(outputs, masks)
#      14 # Backward pass and optimization
#
# File ~/Documents/uni/ZEISS/project/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# ...

# %%
# Sanity check
image, mask = cadis_train_ds[40]

model.eval()
with torch.no_grad():
    output = model(image.unsqueeze(0))['out']

predictions = output.squeeze(0).argmax(dim=0)

# %%
from utils.vis_utils import overlay_mask_on_image

overlay_mask_on_image(image, mask)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
overlay_mask_on_image(image, predictions)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
