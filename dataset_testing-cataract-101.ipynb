# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

with open("./data/insegcat-1-v2/coco-annotations.json", "r") as file:
    data = json.load(file)

data["annotations"][0]
# Out:
# {'id': 49,
#  'image_id': 1,
#  'category_id': 2,
#  'segmentation': [[861.5,
#    686.9,
#    808.9,
#    667.9,
#    768.8,
#    561.3,
#    768.5,
#    549.9,
#    826.5,
#    572.3,
#    899.4,
#    606.7,
#    964.1,
#    720.0,
#    906.9,
#    720.0]],
#  'area': 15119,
#  'bbox': [769.0, 550.0, 195.0, 170.0],
#  'iscrowd': False,
#  'isbbox': False,
#  'color': '#bd1333',
#  'metadata': {}}

# %%
from utils.dataset_utils import CadisDataset, Cataract101Dataset

dataset_1 = CadisDataset("data/cadis", split="train")
dataset_2 = Cataract101Dataset("data/insegcat-1-v2", split="train")

# %%
img_1, mask_1 = dataset_1[10]
img_2, mask_2 = dataset_2[10]

img_1.shape, mask_1.shape, img_2.shape, mask_2.shape
# Out:
# (torch.Size([3, 540, 960]),
#  torch.Size([540, 960]),
#  torch.Size([3, 720, 1280]),
#  torch.Size([720, 1280]))

# %%
from torchvision.transforms.functional import to_pil_image

to_pil_image(img_1)
# Out:
# <PIL.Image.Image image mode=RGB size=960x540>

# %%
to_pil_image(img_2)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
from utils.vis_utils import overlay_mask_on_image, visualize_tensor_image

overlay_mask_on_image(img_1, mask_1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
visualize_tensor_image(img_1)
